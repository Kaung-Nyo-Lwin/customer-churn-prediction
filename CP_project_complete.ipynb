# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %%
df = pd.read_csv('./Datasets/Final/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df['TotalCharges'] =  pd.to_numeric(df['TotalCharges'],errors='coerce')
df.loc[df['TotalCharges'].isnull(),'TotalCharges'] = df.loc[df['TotalCharges'].isnull(),'MonthlyCharges']

# %%
df.drop(columns='customerID',axis=1,inplace=True)

# %%
df['customer_value'] = df['Churn']
df['customer_churn'] = df['Churn']


df['customer_value'].loc[df['TotalCharges'] >= df['TotalCharges'].median()] = "High"
df['customer_value'].loc[df['TotalCharges'] < df['TotalCharges'].median()] = "Low"


# df['customer_churn'].loc[(df['customer_value'] == "Low") & (df['Churn'] == "No")] = '0'
# df['customer_churn'].loc[(df['customer_value'] == "Low") & (df['Churn'] == "Yes")] = '1'
# df['customer_churn'].loc[(df['customer_value'] == "High") & (df['Churn'] == "No")] = '2'
# df['customer_churn'].loc[(df['customer_value'] == "High") & (df['Churn'] == "Yes")] = '3'

df['customer_churn'].loc[(df['customer_value'] == "Low") & (df['Churn'] == "No")] = "Low_No_Churn"
df['customer_churn'].loc[(df['customer_value'] == "Low") & (df['Churn'] == "Yes")] = "Low_Churn"
df['customer_churn'].loc[(df['customer_value'] == "High") & (df['Churn'] == "No")] = "High_No_Churn"
df['customer_churn'].loc[(df['customer_value'] == "High") & (df['Churn'] == "Yes")] = "High_Churn"

# %%
X = df[['gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
       'MonthlyCharges', 'TotalCharges']]

y = df['customer_churn']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1)

# %%
y_train.value_counts()
# Out:
# customer_churn
# 2    2582
# 0    2081
# 1    1089
# 3     586
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTEN
smote = SMOTEN(random_state=0)

X_train_up,y_train_up = smote.fit_resample(X_train,y_train)

# %%
from sklearn.preprocessing import StandardScaler,OrdinalEncoder,OneHotEncoder,MinMaxScaler,StandardScaler
from sklearn.impute import  SimpleImputer
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.compose import ColumnTransformer
# preprocessing pipeline
#1
MonthlyCharges_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])
#2
TotalCharges_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])
#3
gender_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#4
Partner_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#5
Dependents_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#6
PhoneService_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#7
MultipleLines_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#8
InternetService_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#9
OnlineSecurity_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#10
OnlineBackup_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#11
DeviceProtection_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#12
TechSupport_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#13
StreamingTV_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#14
StreamingMovies_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#15
Contract_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#16
PaperlessBilling_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder())
])
#17
PaymentMethod_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('MonthlyCharges_transformer', MonthlyCharges_transformer, ['MonthlyCharges']),
        ('TotalCharges_transformer', TotalCharges_transformer, ['TotalCharges']),
        ('gender_transformer', gender_transformer, ['gender']),
        ('Partner_transformer', Partner_transformer, ['Partner']),
        ('Dependents_transformer', Dependents_transformer, ['Dependents']),
        ('PhoneService_transformer', PhoneService_transformer, ['PhoneService']),
        ('MultipleLines_transformer', MultipleLines_transformer, ['MultipleLines']),
        ('InternetService_transformer', InternetService_transformer, ['InternetService']),
        ('OnlineSecurity_transformer', OnlineSecurity_transformer, ['OnlineSecurity']),
        ('OnlineBackup_transformer', OnlineBackup_transformer, ['OnlineBackup']),
        ('DeviceProtection_transformer', DeviceProtection_transformer, ['DeviceProtection']),
        ('TechSupport_transformer', TechSupport_transformer, ['TechSupport']),
        ('StreamingTV_transformer', StreamingTV_transformer, ['StreamingTV']),
        ('StreamingMovies_transformer', StreamingMovies_transformer, ['StreamingMovies']),
        ('Contract_transformer', Contract_transformer, ['Contract']),
        ('PaperlessBilling_transformer', PaperlessBilling_transformer, ['PaperlessBilling']),
        ('PaymentMethod_transformer', PaymentMethod_transformer, ['PaymentMethod']),
    ],remainder='passthrough',)

pipeline = Pipeline([
    ('preprocessor', preprocessor),
])

# %%
from sklearn.model_selection import GridSearchCV,KFold
from sklearn.ensemble import GradientBoostingClassifier
kfold = KFold(n_splits=5, shuffle=True)


param_grid = {
    "gbc__loss":["log_loss", "exponential"],
    "gbc__learning_rate": [0.1,0.01,0.001],
    "gbc__min_samples_split": np.linspace(0.1, 0.5, 12),
    "gbc__min_samples_leaf": np.linspace(0.1, 0.5, 12),
    "gbc__max_depth":[3, 5, 10, None],
    "gbc__max_features":["log2","sqrt"],
    "gbc__criterion": ["friedman_mse",  "mae"],
    "gbc__subsample":[0.5, 0.618, 0.8, 0.85, 0.9, 0.95, 1.0],
    "gbc__n_estimators":[50, 60, 70, 80, 90, 100, 110,120, 130,140, 150]
    }

for param,values in param_grid.items():
    param_values = {}
    param_values[param] = values
    
    gbc = gbc_pipe = Pipeline([('preprocess',pipeline),('gbc',GradientBoostingClassifier(random_state=0))])

    grid = GridSearchCV(estimator = gbc, 
                        param_grid = param_values, 
                        cv = kfold, 
                        n_jobs = -1, 
                        return_train_score=True, 
                        refit=True,
                        scoring='recall_weighted')

#    Fit your grid_search
    grid.fit(X_train, y_train);  #fit means start looping all the possible parameters
    from sklearn.ensemble import GradientBoostingClassifier

    print(grid.best_params_)
# Out:
# {'gbc__loss': 'log_loss'}
# {'gbc__learning_rate': 0.1}
# {'gbc__min_samples_split': 0.17272727272727273}
# {'gbc__min_samples_leaf': 0.17272727272727273}
# {'gbc__max_depth': 3}
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'gbc__max_features': 'log2'}
# {'gbc__criterion': 'friedman_mse'}
# {'gbc__subsample': 0.95}
# {'gbc__n_estimators': 50}

# %%
tuned_parameters = {'loss': 'log_loss',
'learning_rate': 0.1,
'min_samples_split': 0.17272727272727273,
'min_samples_leaf': 0.17272727272727273,
'max_depth': 3,
'max_features': 'log2',
'criterion': 'friedman_mse',
'subsample': 0.95,
'n_estimators': 50}

# %%
gcb = GradientBoostingClassifier(**tuned_parameters)
model_pipe = Pipeline([('preprocess',pipeline),('gbc',gcb)])
model_pipe.fit(X_train_up, y_train_up)
# Out:
# Pipeline(steps=[('preprocess',
#                  Pipeline(steps=[('preprocessor',
#                                   ColumnTransformer(remainder='passthrough',
#                                                     transformers=[('MonthlyCharges_transformer',
#                                                                    Pipeline(steps=[('imputer',
#                                                                                     SimpleImputer()),
#                                                                                    ('scaler',
#                                                                                     StandardScaler())]),
#                                                                    ['MonthlyCharges']),
#                                                                   ('TotalCharges_transformer',
#                                                                    Pipeline(steps=[('imputer',
# ...

# %%
yhat = model_pipe.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,yhat))
# Out:
#                precision    recall  f1-score   support
#
#    High_Churn       0.45      0.67      0.54        75
# High_No_Churn       0.89      0.78      0.84       278
#     Low_Churn       0.72      0.74      0.73       135
#  Low_No_Churn       0.84      0.82      0.83       217
#
#      accuracy                           0.77       705
#     macro avg       0.73      0.75      0.73       705
#  weighted avg       0.80      0.77      0.78       705

# %%
from sklearn.ensemble import HistGradientBoostingClassifier
# cls_weights = {'High_Churn' : 2,'High_No_Churn' : 1,'Low_Churn' : 1,'Low_No_Churn' : 1}
cls_weights = {0 : 2, 3 : 1, 1 : 1, 2 : 1}

hgbc = HistGradientBoostingClassifier(class_weight=cls_weights)
hgbc_pipe = Pipeline([('preprocess',pipeline),('hgbc',hgbc)])
hgbc_pipe.fit(X_train_up, y_train_up)
# Out:
# Pipeline(steps=[('preprocess',
#                  Pipeline(steps=[('preprocessor',
#                                   ColumnTransformer(remainder='passthrough',
#                                                     transformers=[('MonthlyCharges_transformer',
#                                                                    Pipeline(steps=[('imputer',
#                                                                                     SimpleImputer()),
#                                                                                    ('scaler',
#                                                                                     StandardScaler())]),
#                                                                    ['MonthlyCharges']),
#                                                                   ('TotalCharges_transformer',
#                                                                    Pipeline(steps=[('imputer',
# ...

# %%
yhat = hgbc_pipe.predict(X_test)
print(classification_report(y_test,yhat))
# Out:
#                precision    recall  f1-score   support
#
#    High_Churn       0.42      0.41      0.41        71
# High_No_Churn       0.84      0.85      0.85       278
#     Low_Churn       0.67      0.65      0.66       118
#  Low_No_Churn       0.83      0.84      0.83       238
#
#      accuracy                           0.77       705
#     macro avg       0.69      0.69      0.69       705
#  weighted avg       0.77      0.77      0.77       705

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

param_grid = {
    # "model__loss":["log_loss", "exponential","auto","binary_crossentropy","categorical_crossentropy"],
    "model__learning_rate": [0.1,0.01,0.001],
    "model__min_samples_leaf": [10,20,30,40],
    "model__max_depth":[3, 5, 10, None],
    "model__max_features":[0.1,0.25,0.5,0.75,1],
    # "model__criterion": ["friedman_mse",  "mae"],
    # "model__subsample":[0.5, 0.618, 0.8, 0.85, 0.9, 0.95, 1.0],
    "model__l2_regularization" : [0,0.1,0.99],
    "model__max_iter":[50, 60, 70, 80, 90, 100, 110,120, 130,140, 150]
    }
cls_weights = {0 : 2, 3 : 1, 1 : 1, 2 : 1}

# categorical_features = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod']

import Model_Grid_Search
hgbc = HistGradientBoostingClassifier(class_weight=cls_weights)
hgbc_param = Model_Grid_Search.search(param_grid,model=hgbc,upsample=True)

# %%
hgbc_param
# Out:
# {'learning_rate': 0.1,
#  'min_samples_leaf': 10,
#  'max_depth': None,
#  'max_features': 0.5,
#  'l2_regularization': 0.1,
#  'max_iter': 130}

# %%
# {'learning_rate': 0.1,
#  'min_samples_leaf': 10,
#  'max_depth': None,
#  'max_features': 0.5,
#  'l2_regularization': 0.1,
#  'max_iter': 130}

# %%
# import preprocessing
# from sklearn.pipeline import Pipeline
# X_train, X_test, y_train, y_test = Model_Grid_Search.prepare()
# X_train,y_train = preprocessing.up_sample(X_train,y_train)
# cls_weights = {0 : 2, 3 : 1, 1 : 1, 2 : 1}
# params = {'learning_rate': 0.1,
#      'min_samples_leaf': 10,
#      'max_depth': None,
#      'max_features': 0.5,
#      'l2_regularization': 0.1,
#      'max_iter': 130,
#      'class_weight' : cls_weights}

# hgcb = HistGradientBoostingClassifier(**params)
# pipeline = preprocessing.preprocess_pipeline()
# hgcb_pipe = Pipeline([('preprocess',pipeline),('hgbc',hgcb)])
# hgcb_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  Pipeline(steps=[('preprocessor',
#                                   ColumnTransformer(remainder='passthrough',
#                                                     transformers=[('MonthlyCharges_transformer',
#                                                                    Pipeline(steps=[('imputer',
#                                                                                     SimpleImputer()),
#                                                                                    ('scaler',
#                                                                                     StandardScaler())]),
#                                                                    ['MonthlyCharges']),
#                                                                   ('TotalCharges_transformer',
#                                                                    Pipeline(steps=[('imputer',
# ...

# %%
from sklearn.metrics import classification_report
yhat = hgcb_pipe.predict(X_test)
print(classification_report(y_test,yhat))
# Out:
#                precision    recall  f1-score   support
#
#    High_Churn       0.57      0.57      0.57        69
# High_No_Churn       0.90      0.90      0.90       295
#     Low_Churn       0.66      0.65      0.65       117
#  Low_No_Churn       0.82      0.82      0.82       224
#
#      accuracy                           0.80       705
#     macro avg       0.73      0.73      0.73       705
#  weighted avg       0.80      0.80      0.80       705

# %% [markdown]
# ### Model Comparison

# %%
import preprocessing,model_train,model_evaluate
from imp import reload
reload(preprocessing)
reload(model_train)
reload(model_evaluate)
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingClassifier,HistGradientBoostingClassifier

# %%
X_train, X_test, y_train, y_test = preprocessing.prepare(four_class=False)

tuned_parameters = {'loss': 'log_loss',
'learning_rate': 0.1,
'min_samples_split': 0.17272727272727273,
'min_samples_leaf': 0.17272727272727273,
'max_depth': 3,
'max_features': 'log2',
'criterion': 'friedman_mse',
'subsample': 0.95,
'n_estimators': 50}

gbc_2class = model_train.train(GradientBoostingClassifier,X_train,y_train,params=tuned_parameters)

X_train, y_train = preprocessing.up_sample(X_train,y_train)

gbc_2class_upsample = model_train.train(GradientBoostingClassifier,X_train,y_train,params=tuned_parameters)

# %%
_, X_test, _, y_test = preprocessing.prepare(four_class=False)
two_class = model_evaluate.evaluate_models([(gbc_2class,'gbc_2class'),(gbc_2class_upsample,'gbc_2class_upsample')],X_test,y_test)
two_class
# Out:
#                 Models  Potential Risk in Currency  Risk Factor  \
# 0           gbc_2class                    247608.9     0.766025
# 1  gbc_2class_upsample                    190178.7     0.588354
#
#    Number of wrong predictions  False Negatives
# 0                          147              100
# 1                          178               63

# %%
X_train, X_test, y_train, y_test = preprocessing.prepare()

tuned_parameters = {'loss': 'log_loss',
'learning_rate': 0.1,
'min_samples_split': 0.17272727272727273,
'min_samples_leaf': 0.17272727272727273,
'max_depth': 3,
'max_features': 'log2',
'criterion': 'friedman_mse',
'subsample': 0.95,
'n_estimators': 50}

gbc_4class = model_train.train(GradientBoostingClassifier,X_train,y_train,params=tuned_parameters)

X_train, y_train = preprocessing.up_sample(X_train,y_train)

gbc_4class_upsample = model_train.train(GradientBoostingClassifier,X_train,y_train,params=tuned_parameters)

X_train, X_test, y_train, y_test = preprocessing.prepare()

params = {'learning_rate': 0.1,
     'min_samples_leaf': 10,
     'max_depth': None,
     'max_features': 0.5,
     'l2_regularization': 0.1,
     'max_iter': 130
}

hgbc_4class = model_train.train(HistGradientBoostingClassifier,X_train,y_train,params=params)

X_train, y_train = preprocessing.up_sample(X_train,y_train)

hgbc_4class_upsample = model_train.train(HistGradientBoostingClassifier,X_train,y_train,params=params)

cls_weights = {0 : 2, 
               1 : 1, 
               2 : 1, 
               3 : 1}
params_class = {'learning_rate': 0.1,
     'min_samples_leaf': 10,
     'max_depth': None,
     'max_features': 0.5,
     'l2_regularization': 0.1,
     'max_iter': 130,
     'class_weight' : cls_weights}

hgbc_4class_upsample_class_weight1 = model_train.train(HistGradientBoostingClassifier,X_train,y_train,params=params_class)

cls_weights = {0 : 3, 
               1 : 1, 
               2 : 2, 
               3 : 1}
params_class = {'learning_rate': 0.1,
     'min_samples_leaf': 10,
     'max_depth': None,
     'max_features': 0.5,
     'l2_regularization': 0.1,
     'max_iter': 130,
     'class_weight' : cls_weights}

hgbc_4class_upsample_class_weight2 = model_train.train(HistGradientBoostingClassifier,X_train,y_train,params=params_class)


cls_weights = {0 : 4, 
               1 : 1, 
               2 : 1, 
               3 : 1}
params_class = {'learning_rate': 0.1,
     'min_samples_leaf': 10,
     'max_depth': None,
     'max_features': 0.5,
     'l2_regularization': 0.1,
     'max_iter': 130,
     'class_weight' : cls_weights}

hgbc_4class_upsample_class_weight4 = model_train.train(HistGradientBoostingClassifier,X_train,y_train,params=params_class)

# %%
# gradeint boosting parameters
gbc_parameters = {'loss': 'log_loss',
'learning_rate': 0.1,
'min_samples_split': 0.17272727272727273,
'min_samples_leaf': 0.17272727272727273,
'max_depth': 3,
'max_features': 'log2',
'criterion': 'friedman_mse',
'subsample': 0.95,
'n_estimators': 50}

# histogram-based gradeint boosting parameters
hgc_parameters = {'learning_rate': 0.1,
     'min_samples_leaf': 10,
     'max_depth': None,
     'max_features': 0.5,
     'l2_regularization': 0.1,
     'max_iter': 130}

# %%
model_list = [
            (gbc_4class,'gbc_4class'),
            (gbc_4class_upsample,'gbc_4class_upsample'),
            (hgbc_4class ,'hgbc_4class'),
            (hgbc_4class_upsample ,'hgbc_4class_upsample'),
            (hgbc_4class_upsample_class_weight1 ,'hgbc_4class_upsample_class_weight1'),
            (hgbc_4class_upsample_class_weight2,'hgbc_4class_upsample_class_weight2'),
            (hgbc_4class_upsample_class_weight3,'hgbc_4class_upsample_class_weight3'),
            (hgbc_4class_upsample_class_weight4,'hgbc_4class_upsample_class_weight4')
]

# %%
_, X_test, _, y_test = preprocessing.prepare()
four_class = model_evaluate.evaluate_models(model_list,X_test,y_test)

# %%
four_class
# Out:
#                                Models  Potential Risk in Currency  \
# 0                          gbc_4class                   277095.30
# 1                 gbc_4class_upsample                   168376.30
# 2                         hgbc_4class                   246049.50
# 3                hgbc_4class_upsample                   236796.05
# 4  hgbc_4class_upsample_class_weight1                   187950.35
# 5  hgbc_4class_upsample_class_weight2                   188011.10
# 6  hgbc_4class_upsample_class_weight3                   186503.45
# 7  hgbc_4class_upsample_class_weight4                   185005.20
#
#    Risk Factor  Number of wrong predictions  False Negatives
# 0     0.857247                          145              105
# 1     0.520904                          191               64
# 2     0.761201                          157               89
# 3     0.732573                          167               90
# 4     0.581460                          168               76
# ...

# %%
y_pred = hgbc_4class_upsample_class_weight4.predict(X_test)
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#   High_Churn       0.34      0.47      0.40        70
# High_NoChurn       0.85      0.78      0.81       288
#    Low_Churn       0.60      0.64      0.62       110
#  Low_NoChurn       0.82      0.79      0.81       237
#
#     accuracy                           0.73       705
#    macro avg       0.65      0.67      0.66       705
# weighted avg       0.75      0.73      0.74       705

# %%
two_class
# Out:
#                 Models  Potential Risk in Currency  Risk Factor  \
# 0           gbc_2class                    247608.9      0.15336
# 1  gbc_2class_upsample                    190178.7      0.11779
#
#    Number of wrong predictions  False Negatives
# 0                          147              100
# 1                          178               63

# %%
import pandas as pd
report = pd.concat([two_class,four_class],axis=0)
report.reset_index(inplace=True)
report.drop('index',axis=1,inplace=True)
report
# Out:
#                                Models  Potential Risk in Currency  \
# 0                          gbc_2class                   247608.90
# 1                 gbc_2class_upsample                   190178.70
# 2                          gbc_4class                   277095.30
# 3                 gbc_4class_upsample                   168376.30
# 4                         hgbc_4class                   246049.50
# 5                hgbc_4class_upsample                   236796.05
# 6  hgbc_4class_upsample_class_weight1                   187950.35
# 7  hgbc_4class_upsample_class_weight2                   188011.10
# 8  hgbc_4class_upsample_class_weight3                   186503.45
# 9  hgbc_4class_upsample_class_weight4                   185005.20
#
#    Risk Factor  Number of wrong predictions  False Negatives
# 0     0.766025                          147              100
# 1     0.588354                          178               63
# ...

# %%
report.to_csv('./evaluation_results.csv')

# %%
report.columns
# Out:
# Index(['Models', 'Potential Risk in Currency', 'Risk Factor',
#        'Number of wrong predictions', 'False Negatives'],
#       dtype='object')

# %%
report.sort_values('Risk Factor').reset_index()[['Models', 'Potential Risk in Currency', 'Risk Factor',
       'Number of wrong predictions', 'False Negatives']]
# Out:
#                                Models  Potential Risk in Currency  \
# 0                 gbc_4class_upsample                   168376.30
# 1  hgbc_4class_upsample_class_weight4                   185005.20
# 2  hgbc_4class_upsample_class_weight3                   186503.45
# 3  hgbc_4class_upsample_class_weight1                   187950.35
# 4  hgbc_4class_upsample_class_weight2                   188011.10
# 5                 gbc_2class_upsample                   190178.70
# 6                hgbc_4class_upsample                   236796.05
# 7                         hgbc_4class                   246049.50
# 8                          gbc_2class                   247608.90
# 9                          gbc_4class                   277095.30
#
#    Risk Factor  Number of wrong predictions  False Negatives
# 0     0.520904                          191               64
# 1     0.572349                          190               77
# ...

# %%
import pickle

filename = './model/customer_churn.model'
pickle.dump(gbc_4class_upsample, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
loaded_model
# Out:
# Pipeline(steps=[('preprocess',
#                  Pipeline(steps=[('preprocessor',
#                                   ColumnTransformer(remainder='passthrough',
#                                                     transformers=[('MonthlyCharges_transformer',
#                                                                    Pipeline(steps=[('imputer',
#                                                                                     SimpleImputer()),
#                                                                                    ('scaler',
#                                                                                     StandardScaler())]),
#                                                                    ['MonthlyCharges']),
#                                                                   ('TotalCharges_transformer',
#                                                                    Pipeline(steps=[('imputer',
# ...
